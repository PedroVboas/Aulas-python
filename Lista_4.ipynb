# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroVboas/Aulas-python/blob/master/Lista_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Disciplina: Probabilidade e Estatística
#Aluno: Pedro Henrique Vilas Boas Oliveira - 2014290056
#Lista 4


#Exercício 1:
#Inserir os dados
'''lado = int(input("Digite o número de lados do polígono regular: "))
medida = int(input("Digite a medida do lado: "))
#Calculo para cada polígono
area_triangulo = medida * medida / 2
area_quadrado = medida * medida
#Condições para saber o resultado
if lado == 3:
  print("Triângulo! Valor da área = ", area_triangulo)
elif lado == 4:
  print("Quadrado! Valor da área = ", area_quadrado)
elif lado == 5:
  print("Pentágono!") 
else:
  print("Não foi possível encontrar o resultado!")'''


#Exercício 2:
'''#Inserir os dados
lado = int(input("Digite o número de lados do polígono regular: "))
medida = int(input("Digite a medida do lado: "))

#Calculo para cada polígono
area_triangulo = medida * medida / 2
area_quadrado = medida * medida

#Condições para saber o resultado
if lado == 3:
  print("Triângulo! Valor da área = ", area_triangulo)
elif lado == 4:
  print("Quadrado! Valor da área = ", area_quadrado)
elif lado == 5:
  print("Pentágono!")
elif lado < 3:
  print("Não é um polígono!") 
else:
  print("Polígono não identificado!")'''


#Exercício 3:
'''#Inserir dados
Valor1 = int(input("Digite o primeiro valor: "))
Valor2 = int(input("Digite o segundo valor: "))
Valor3 = int(input("Digite o terceiro valor: "))

#condições para saber qual o maior valor
if Valor1 > Valor2 and Valor1 > Valor3:
  print("Maior valor: ", Valor1)
elif Valor2 > Valor1 and Valor2 > Valor3:
  print("Maior valor: ", Valor2)
else:
  print("Maior valor: ", Valor3)'''


#Exercício 4:
'''#Inserir dados
Medida1 = int(input("Digite a primeira medida do triângulo: "))
Medida2 = int(input("Digite a segunda medida do triângulo "))
Medida3 = int(input("Digite a terceira medida do triângulo: "))

#Condição para saber qual é o triângulo
if Medida1 == Medida2 and Medida2 == Medida3:
  print("Equilátero")
elif Medida1 == Medida2 or Medida2 == Medida3 or Medida1 == Medida3:
  print("Isósceles")
else:
  print("Escaleno")'''


#Exercício 5:
'''#Inserir dados
Valor1 = int(input("Digite o primeiro ângulo: "))
Valor2 = int(input("Digite o segundo ângulo: "))
Valor3 = int(input("Digite o terceiro ângulo: "))

#condição para saber qual é o valor do triângulo
if Valor1 + Valor2 + Valor3 == 90:
  print("Retângulo")
elif Valor1 + Valor2 + Valor3 > 90:
  print("Obtusângulo")
else:
  print("Acutângulo")'''


#Exercício 6:
'''Num = int(input("Digite até que número você quer imprimir: ")) #Inserir dados

for _ in range(0,Num +1): #loop que repete até o valor solicitado
  print(_)'''


#Exercício 7:
'''Num = input("Insira um número (1), (2), (3) ou (4): ")#Inserir dados
if Num != "1" and Num != "2" and Num != "3" and Num != "4": #condição para dar continuação ao while enquando for verdadeiro (para poder repetir o print("Entrada Inválida!"))
  while True:
    print("Entrada inválida!")
    Num = input("Insira um número (1), (2), (3) ou (4): ")
    if Num == "1" or Num == "2" or Num == "3" or Num == "4":
      break 
if Num == "1" or Num == "2" or Num == "3" or Num == "4":
  print("Número digitado: ",Num)'''


#Exercício 8:
'''Lista = [] #Declarando uma lista
while True: #while para repetir o inserimento de dados
    Num = int(input("Insira um número ou digite 0 para dar fim a operação: "))
    Lista.append(Num) #Adicionando o input (Num) na lista para poder saber o maior número
    if Num == 0:
      print("Fim da execução!")
      break
print ("Maior número:",max(Lista))'''


#Exercício 9:
'''Num = int(input("Digite um número positivo de 4 dígitos: ")) #Inserir dados
#Calculo para cada decomposição dos dígitos
unidade = Num % 10
print("Unidade = ",unidade)
dezena = Num // 10 % 10
print("Dezena = ",dezena)
centena = Num // 100 % 10
print("Centena = ",centena)
milhar = Num // 1000 % 10
print("Milhar = ",milhar)'''
# Out:
# Digite um número positivo de 4 dígitos: 1245
# Unidade =  5
# Dezena =  4
# Centena =  2
# Milhar =  1
